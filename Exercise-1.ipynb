# %%
ice_cream_rating = 7
sleeping_rating = 8

# %%
first_name = input()
last_name = input()
# Out:
#  Jarret
#  Pidgeon

# %%
print(last_name)
# Out:
# Pidgeon

# %%
(ice_cream_rating + sleeping_rating)/2
# Out:
# 7.5

# %%
happiness_rating = 7.5

# %% [markdown]
# type(happiness_rating)

# %% [markdown]
# type(first_name)

# %% [markdown]
# type(ice_cream_rating)

# %%
f"Hello, my name is first_name and I give ice cream eating a score of {ice_cream_rating} out of 10."
# Out:
# 'Hello, my name is first_name and I give ice cream eating a score of 7 out of 10.'

# %%
f"Hi, my name is {first_name + last_name} and I give sleeping a score of sleeping_rating out of 10."
# Out:
# 'Hi, my name is JarretPidgeon and I give sleeping a score of sleeping_rating out of 10.'

# %%
f"Based on the factors above, my happiness rating is a {happiness_rating} out of 10, or 75%!"
# Out:
# 'Based on the factors above, my happiness rating is a 7.5 out of 10, or 75%!'
